# %% [markdown]
# # 1.Read the dataset to python environment.

# %%
import pandas as pd

asg_df = pd.read_excel('iris.xlsx')
print(asg_df)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
asg_df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
asg_df['SL']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
# 30     4.8
# 31     5.4
# 32     5.2
# 33     5.5
# 34     4.9
# 35     5.0
# 36     5.5
# 37     4.9
# 38     4.4
# 39     5.1
# 40     5.0
# 41     4.5
# 42     4.4
# 43     5.0
# 44     5.1
# 45     4.8
# 46     5.1
# 47     4.6
# 48     5.3
# 49     5.0
# 50     7.0
# 51     6.4
# 52     6.9
# 53     5.5
# 54     6.5
# 55     5.7
# 56     6.3
# 57     4.9
# 58     6.6
# 59     5.2
# 60     5.0
# 61     5.9
# 62     6.0
# 63     6.1
# 64     5.6
# 65     6.7
# 66     5.6
# 67     5.8
# 68     6.2
# 69     5.6
# 70     5.9
# 71     6.1
# 72     6.3
# 73     6.1
# 74     6.4
# 75     6.6
# ...

# %%
asg_df['SW']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
# 30     3.1
# 31     3.4
# 32     4.1
# 33     4.2
# 34     3.1
# 35     3.2
# 36     3.5
# 37     3.1
# 38     3.0
# 39     3.4
# 40     3.5
# 41     2.3
# 42     3.2
# 43     3.5
# 44     3.8
# 45     3.0
# 46     3.8
# 47     3.2
# 48     3.7
# 49     3.3
# 50     3.2
# 51     3.2
# 52     3.1
# 53     2.3
# 54     2.8
# 55     2.8
# 56     3.3
# 57     2.4
# 58     2.9
# 59     2.7
# 60     2.0
# 61     3.0
# 62     2.2
# 63     2.9
# 64     2.9
# 65     3.1
# 66     3.0
# 67     2.7
# 68     2.2
# 69     2.5
# 70     3.2
# 71     2.8
# 72     2.5
# 73     2.8
# 74     2.9
# 75     3.0
# ...

# %%
asg_df['PL']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
# 30     1.6
# 31     1.5
# 32     1.5
# 33     1.4
# 34     1.5
# 35     1.2
# 36     1.3
# 37     1.5
# 38     1.3
# 39     1.5
# 40     1.3
# 41     1.3
# 42     1.3
# 43     1.6
# 44     1.9
# 45     1.4
# 46     1.6
# 47     1.4
# 48     1.5
# 49     1.4
# 50     4.7
# 51     4.5
# 52     4.9
# 53     4.0
# 54     4.6
# 55     4.5
# 56     4.7
# 57     3.3
# 58     4.6
# 59     3.9
# 60     3.5
# 61     4.2
# 62     4.0
# 63     4.7
# 64     3.6
# 65     4.4
# 66     4.5
# 67     4.1
# 68     4.5
# 69     3.9
# 70     4.8
# 71     4.0
# 72     4.9
# 73     4.7
# 74     4.3
# 75     4.4
# ...

# %%
asg_df['PW']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
# 5      0.4
# 6      0.3
# 7      0.2
# 8      0.2
# 9      0.1
# 10     0.2
# 11     0.2
# 12     0.1
# 13     0.1
# 14     0.2
# 15     0.4
# 16     0.4
# 17     0.3
# 18     0.3
# 19     0.3
# 20     0.2
# 21     0.4
# 22     0.2
# 23     0.5
# 24     0.2
# 25     0.2
# 26     0.4
# 27     0.2
# 28     0.2
# 29     0.2
# 30     0.2
# 31     0.4
# 32     0.1
# 33     0.2
# 34     0.1
# 35     0.2
# 36     0.2
# 37     0.1
# 38     0.2
# 39     0.2
# 40     0.3
# 41     0.3
# 42     0.2
# 43     0.6
# 44     0.4
# 45     0.3
# 46     0.2
# 47     0.2
# 48     0.2
# 49     0.2
# 50     1.4
# 51     1.5
# 52     1.5
# 53     1.3
# 54     1.5
# 55     1.3
# 56     1.6
# 57     1.0
# 58     1.3
# 59     1.4
# 60     1.0
# 61     1.5
# 62     1.0
# 63     1.4
# 64     1.3
# 65     1.4
# 66     1.5
# 67     1.0
# 68     1.5
# 69     1.1
# 70     1.8
# 71     1.3
# 72     1.5
# 73     1.2
# 74     1.3
# 75     1.4
# ...

# %% [markdown]
# # 3.Calculate the mean of each column of the dataset

# %%
asg_df.mean(axis = 0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
null=asg_df.isnull()
print(null)
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# 5    False  False  False  False           False
# 6    False  False  False  False           False
# 7    False  False  False  False           False
# 8    False  False  False  False           False
# 9    False  False  False  False           False
# 10   False  False  False  False           False
# 11   False  False  False  False           False
# 12   False  False  False  False           False
# 13   False  False  False  False           False
# 14   False  False  False  False           False
# 15   False  False  False  False           False
# 16   False  False  False  False           False
# 17   False  False  False  False           False
# 18   False  False  False  False           False
# ...

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vis_1=asg_df[['SL','SW','PL','PW']]
sns.pairplot(vis_1)

# %%
asg_df[['SL','SW','PL','PW']].plot.hist()
plt.title('Assignment')
# Out:
# Text(0.5, 1.0, 'Assignment')

# %%
y = np.array([49, 50, 50])
mylabels = ["Iris-setosa=49", "Iris-versicolor=50", "Iris-virginica=50"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
sns.stripplot(x='SL',y='SW',data=asg_df)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
sns.stripplot(x='PL',y='PW',data=asg_df)
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>
